# %%
import numpy as np
from PIL import Image

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
path = '/Users/yosuniiiii/Deep_learning/jupyter_notebook/images/mong_1.jpeg'

image_pil = Image.open(path)
image = np.array(image_pil)

# %% [markdown]
# ##  이미지 들여다보기

# %%
image.shape
# Out:
# (3024, 3024, 3)

# %%
np.min(image), np.max(image)
# Out:
# (0, 255)

# %% [markdown]
# ## 그래프로 시각화 하기

# %%
plt.hist(image.ravel(), 256, [0, 256])
plt.show()

# %% [markdown]
# ##  그림으로 나타내기

# %%
plt.imshow(image)
plt.show()

# %% [markdown]
# ##  이미지 흑백으로 열기

# %%
image_pil = Image.open(path).convert("L")
image_bw = np.array(image_pil)

# %%
image_bw.shape
# Out:
# (3024, 3024)

# %%
plt.imshow(image_bw, 'gray')

# %%
plt.imshow(image_bw, "jet")
plt.colorbar()
plt.show() # 높을수록 발간색 낮을수록 파란색

# %% [markdown]
# ##  두번째 이미지도 활용 함께 해보기

# %%
path_2 = '/Users/yosuniiiii/Deep_learning/jupyter_notebook/images/mong_2.jpeg'

image_pil_2 = Image.open(path_2)
image_2 = np.array(image_pil_2)

# %%
plt.imshow(image_2)
plt.show()

# %%
image_2.shape, image.shape
# Out:
# ((700, 700, 3), (3024, 3024, 3))

# %% [markdown]
# ##  만약 이미지 사이즈가 다를 경우 이미지 사이즈를 합치기 해야됨

# %%
import cv2

# %%
image_1 = cv2.resize(image, (700, 700)) 
image_1.shape # 사이즈 바꿈 !
# Out:
# (700, 700, 3)

# %%
image_1.shape, image_2.shape # 같아져따아~~
# Out:
# ((700, 700, 3), (700, 700, 3))

# %% [markdown]
# ##  이미지 합치기

# %%
plt.imshow(image_1)
plt.imshow(image_2, alpha= 0.3) # alpha값으로 투명도를 줄 수 있음 
plt.show()
